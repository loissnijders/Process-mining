# %%
from pm4py.objects.conversion.log import converter as xes_converter
from pm4py.objects.log.importer.xes import importer as xes_importer

# %%
log = xes_importer.apply('C:/Users/20203203/Documents/data science Y2/Quartile 3/Process mining/data/BPI_Challenge_2012.xes.gz')
pd = xes_converter.apply(log, variant=xes_converter.Variants.TO_DATA_FRAME)

# %%
pd
# Out:
#        org:resource lifecycle:transition            concept:name  \
# 0               112             COMPLETE             A_SUBMITTED
# 1               112             COMPLETE       A_PARTLYSUBMITTED
# 2               112             COMPLETE           A_PREACCEPTED
# 3               112             SCHEDULE  W_Completeren aanvraag
# 4               NaN                START  W_Completeren aanvraag
# ...             ...                  ...                     ...
# 262195          112             COMPLETE       A_PARTLYSUBMITTED
# 262196          112             SCHEDULE      W_Afhandelen leads
# 262197        11169                START      W_Afhandelen leads
# 262198        11169             COMPLETE              A_DECLINED
# 262199        11169             COMPLETE      W_Afhandelen leads
#
#                           time:timestamp                     case:REG_DATE  \
# 0       2011-10-01 00:38:44.546000+02:00  2011-10-01 00:38:44.546000+02:00
# ...

# %%
pd.to_csv('data/data_csv.csv')

# %%
pd.describe()
# Out:
#        org:resource lifecycle:transition            concept:name  \
# count        244190               262200                  262200
# unique           68                    3                      24
# top             112             COMPLETE  W_Completeren aanvraag
# freq          45687               164506                   54850
#
#                           time:timestamp                     case:REG_DATE  \
# count                             262200                            262200
# unique                            248189                             13087
# top     2012-01-05 10:01:25.057000+01:00  2011-11-15 13:42:45.592000+01:00
# freq                                   4                               175
#
#        case:concept:name case:AMOUNT_REQ
# count             262200          262200
# unique             13087             631
# top               185548            5000
# freq                 175           32988

# %% [markdown]
# # Italian road fines data

# %%
log_it = xes_importer.apply('C:/Users/20203203/Documents/data science Y2/Quartile 3/Process mining/data/Road_Traffic_Fine_Management_Process.xes.gz')
pd_it = xes_converter.apply(log, variant=xes_converter.Variants.TO_DATA_FRAME)

# %%
pd_it
# Out:
#        org:resource lifecycle:transition            concept:name  \
# 0               112             COMPLETE             A_SUBMITTED
# 1               112             COMPLETE       A_PARTLYSUBMITTED
# 2               112             COMPLETE           A_PREACCEPTED
# 3               112             SCHEDULE  W_Completeren aanvraag
# 4               NaN                START  W_Completeren aanvraag
# ...             ...                  ...                     ...
# 262195          112             COMPLETE       A_PARTLYSUBMITTED
# 262196          112             SCHEDULE      W_Afhandelen leads
# 262197        11169                START      W_Afhandelen leads
# 262198        11169             COMPLETE              A_DECLINED
# 262199        11169             COMPLETE      W_Afhandelen leads
#
#                           time:timestamp                     case:REG_DATE  \
# 0       2011-10-01 00:38:44.546000+02:00  2011-10-01 00:38:44.546000+02:00
# ...
